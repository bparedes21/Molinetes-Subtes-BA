# %%
from datetime import datetime
import pandas as pd
import time
import numpy as np

# %%
import Graficos_LineaSubtes

# %%
dataframes_lineas=pd.read_csv('df_final_name.csv',sep=",")

# %%
Graficos_LineaSubtes.generar_tabla_estaciones_top(dataframes_lineas)

# %%
Graficos_LineaSubtes.generar_tabla_promedio_pasajeros(dataframes_lineas)
# Out:
#   ID_Línea  Promedio_Pasajeros
# 2   LineaC           3267835.0
# 3   LineaD           2880205.0
# 1   LineaB           2876285.0
# 0   LineaA           2048018.0
# 5   LineaH           1754676.0
# 4   LineaE            963541.0

# %%
Graficos_LineaSubtes.grafico_pasajeros_por_hora(dataframes_lineas)

# %%
Graficos_LineaSubtes.grafico_pasajeros_por_linea(dataframes_lineas)
# Out:
# c:\Users\roxy_\Graficos_LineaSubtes.py:195: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
Graficos_LineaSubtes.guardar_grafico_pasajeros_por_estacion_linea_B(dataframes_lineas)
# Out:
# c:\Users\roxy_\Graficos_LineaSubtes.py:243: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
Graficos_LineaSubtes.guardar_grafico_estacion_mayor_pasajeros(dataframes_lineas)

# %%
Graficos_LineaSubtes.guardar_grafico_pasajeros_por_mes(dataframes_lineas)
# Out:
# c:\Users\roxy_\Graficos_LineaSubtes.py:317: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %%
Graficos_LineaSubtes.guardar_tabla_suma_pasajeros(dataframes_lineas)
